# %%
list = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

i = 1

while i < 3:
  for user_name in list:
    print(user_name)

  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
